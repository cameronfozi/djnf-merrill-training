# %% [markdown]
# # Who is voting in Alameda County?
# ## Cameron Fozi
# ### DJNF Data Journalism Training @ Merrill College

# %% [markdown]
# In the affluent, hillside suburbs of Berkeley, voter turnout is high. More than 80% of the voting-age population, in some census tracts, voted in the 2022 general election. But such cannot be said for the flatlands of Oakland, Southside Berkeley and many of Alameda County's bayside neighborhoods.

# %% [markdown]
# While news coverage from across the country in recent years suggests growing interest in voter suppression and apathy, few Bay Area news organizations have risen to the task of covering the phenomena locally.

# %%
# %%HTML
# <div class="flourish-embed flourish-scatter" data-src="visualisation/18259297"><script src="https://public.flourish.studio/resources/embed.js"></script></div>
# Out:
# <div class="flourish-embed flourish-scatter" data-src="visualisation/18259297"><script src="https://public.flourish.studio/resources/embed.js"></script></div>

# %% [markdown]
# Across Alameda County, residents of whiter census tracts with fewer living below the poverty level voted in the 2022 general election in droves, according to poverty level and demographic data from the American Community Survey and voter-turnout data from Berkeley Law. However, residents of poorer, less white Alameda County census tracts have lower shares of voting residents.

# %%
# %%HTML
# <iframe title="Voter turnout in the 2022 general election varied widely in the Bay Area" aria-label="Map" id="datawrapper-chart-zzvpC" src="https://datawrapper.dwcdn.net/zzvpC/1/" scrolling="no" frameborder="0" style="width: 0; min-width: 100% !important; border: none;" height="790" data-external="1"></iframe><script type="text/javascript">!function(){"use strict";window.addEventListener("message",(function(a){if(void 0!==a.data["datawrapper-height"]){var e=document.querySelectorAll("iframe");for(var t in a.data["datawrapper-height"])for(var r=0;r<e.length;r++)if(e[r].contentWindow===a.source){var i=a.data["datawrapper-height"][t]+"px";e[r].style.height=i}}}))}();
# </script>
# Out:
# <iframe title="Voter turnout in the 2022 general election varied widely in the Bay Area" aria-label="Map" id="datawrapper-chart-zzvpC" src="https://datawrapper.dwcdn.net/zzvpC/1/" scrolling="no" frameborder="0" style="width: 0; min-width: 100% !important; border: none;" height="790" data-external="1"></iframe><script type="text/javascript">!function(){"use strict";window.addEventListener("message",(function(a){if(void 0!==a.data["datawrapper-height"]){var e=document.querySelectorAll("iframe");for(var t in a.data["datawrapper-height"])for(var r=0;r<e.length;r++)if(e[r].contentWindow===a.source){var i=a.data["datawrapper-height"][t]+"px";e[r].style.height=i}}}))}();
# </script>

# %%
import pandas as pd
from itables import show

data = pd.read_csv("table_data.csv")
show(data)
# Out:
# <table id="itables_8aac0bb6_87e5_41c6_999c_0d2665cd7b08" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>Unnamed: 0</th>
#       <th>Total voting-age population</th>
#       <th>Census tract</th>
#       <th>Voters in 2022</th>
#       <th>Voting-age residents who voted in 2022 (%)</th>
#       <th>American Indian or Alaska Native (%)</th>
#       <th>Asian (%)</th>
#       <th>Black (%)</th>
#       <th>Native Hawaiian or other Pacific Islander (%)</th>
#       <th>White (%)</th>
#       <th>Hispanic or Latino (%)</th>
#       <th>Mixed race (%)</th>
#       <th>Place</th>
#       <th>Below poverty level (%)</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# ...

# %% [markdown]
# News coverage from across the country in recent years reveals an interest in covering voter suppression, but few news organizations local to the Bay Area have covered it.
#
# The Associated Press [reported](https://www.eastbaytimes.com/2024/05/23/naacp-fund-seeks-to-close-black-voter-registration-and-turnout-gaps-ahead-of-the-november-election/) in May the NAACP had made attempts at increasing voter registration among Black adults. Local News Matters, the nonprofit publication of Bay City News, [reported](https://localnewsmatters.org/2023/08/30/bay-areas-young-voters-are-registering-at-lower-rates-organizers-are-combating-this-ahead-of-2024-election/) in 2023 that young voters that year were registering at lower rates than they did in 2021.
#
# In 2022, the NAACP asked the Alameda County Registrar of Voters to recount the votes from the mayoral election in Oakland. According to CBS News Bay Area, the registrar charged the organization $21,000 for each day the registrar recounted the votes; the NAACP called it voter suppression.
#
# By reporting on demographic disparities in voter turnout, Bay City News and Local News Matters could serve an apparent interest in voting dynamics among local communities.
#
# Much of the preliminary data analysis required for a story on racial and socioeconomic disparities in voter turnout in Alameda County is complete. But little has been done to explain why this is the case.
#
# The data may come to life following interviews with voter-turnout experts and Bay Area residents. In the Bay Area, there are a number of academics and social-justice organizations focusing on voter turnout and registration. This story would draw from a wealth of sources in the Bay Area, ready to speak on voter trends in the Area.

# %% [markdown]
# Full racial and socioecomic profiles are available in the table above by sorting the "Voting-age residents who voted (%) column."

# %% [markdown]
# Further analysis may investigate the correlation between the voting population and socioeconomic status in Alameda County census tracts. Moreover, this analysis could easily be extended to the 8- or 13-county Bay Area covered by Bay City News or even the entire state of California.
#
# While this analysis had originally planned to use the census block as a unit of analysis, there were about 700 census blocks of Alameda County’s approximately 18,500 for which there were no residents or the number of voters exceeded the number of voting-age residents, as recorded by the 2022 American Community Survey. Another avenue of exploration could use data from the 2020 decennial census, which are potentially more accurate, and compare them to voter turnout rates from the 2020 general election.
#
# Finally, time series analysis of voter turnout across general elections may also reveal trends with respect to demographic groups’ voting trends over time.

# %% [markdown]
# To see first part of data analysis in Python, which analyzed voter turnout by race, see this [file](https://github.com/cameronfozi/djnf-merrill-training/blob/main/djnf-data-work/preliminary_alameda.ipynb).
#
# To see second part of data analysis in Python, which analyzed voter turnout by race and the percent of the population below the poverty level, see this [file](https://github.com/cameronfozi/djnf-merrill-training/blob/main/djnf-data-work/socioeconomic_alameda.ipynb).
